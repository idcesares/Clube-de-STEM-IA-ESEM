# %% [markdown]
# ### Importando as bibliotecas principais

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Preparando os dados de teste

# %%
x_numpy = np.array([5,7,2,9,4,10,9,4,6,1])
y_numpy = np.array([1,1,0,1,0,1,1,0,1,0])

# %%
# Transofrmando os numpy arrays em tensors
x = torch.from_numpy(x_numpy.astype(np.float32))
y = torch.from_numpy(y_numpy.astype(np.float32))

# %%
# Reshaping os tensors
y = y.view(y.shape[0], 1)
x = x.view(x.shape[0], 1)

# %% [markdown]
# ### Visualizando os dados de teste

# %%
print(x.shape)
print(y.shape)

plt.plot(x_numpy, y_numpy, 'ro')
# Out:
# torch.Size([10, 1])
# torch.Size([10, 1])

# %% [markdown]
# ### Classe de Regressão Logística

# %%
class RegressaoLogistica(nn.Module):
  def __init__(self, n_input, n_output):
    super(RegressaoLogistica, self).__init__()
    self.Linear = nn.Linear(n_input, 1)

  def forward(self, x):
    y_hat = torch.sigmoid(self.Linear(x))
    return y_hat

# %% [markdown]
# ### Definições do modelo

# %%
input_size = 1
output_size = 1
model = RegressaoLogistica(1,1)

# %% [markdown]
# ### Definição da Função de custo e Otimizador

# %%
learning_rate = 0.01
criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
print (model.parameters())
# Out:
# <generator object Module.parameters at 0x00000206BD018AC0>

# %% [markdown]
# ### Loop de treinamento

# %%
num_epochs = 2000
contador_custo = []
for epoch in range(num_epochs):
  # Forward pass and loos
  y_hat = model(x)
  loss = criterion(y_hat, y)
  contador_custo.append(loss)
  # Backward pass (calcular gradientes)
  loss.backward()
  # Update (atualizar os pesos)
  optimizer.step()
  if (epoch+1)%10 == 0:
      print("===============================")
      print('Epoch: ', epoch)
      print('Custo: {:.20f}'.format(loss.item())) 
      print('m: {:.5f}'.format(model.Linear.weight.data.detach().item()))
      print('m (gradiente): {:.5f}'.format(model.Linear.weight.grad.detach().item()))
      print('b: {:.5f}'.format(model.Linear.bias.data.detach().item()))
      print('b (gradiente): {:.5f}'.format(model.Linear.bias.grad.detach().item()))
    
  # Limpar o otimizador
  optimizer.zero_grad()
# Out:
# 6757
# b (gradiente): 0.12867
# ===============================
# Epoch:  629
# Custo: 0.46014809608459472656
# m: 0.28281
# m (gradiente): -0.02075
# b: -0.48040
# b (gradiente): 0.12814
# ===============================
# Epoch:  639
# Custo: 0.45846971869468688965
# m: 0.28489
# m (gradiente): -0.02068
# b: -0.49319
# b (gradiente): 0.12760
# ===============================
# Epoch:  649
# Custo: 0.45680528879165649414
# m: 0.28695
# m (gradiente): -0.02061
# b: -0.50592
# b (gradiente): 0.12707
# ===============================
# Epoch:  659
# Custo: 0.45515456795692443848
# m: 0.28901
# m (gradiente): -0.02055
# b: -0.51860
# b (gradiente): 0.12654
# ===============================
# Epoch:  669
# Custo: 0.45351749658584594727
# m: 0.29106
# m (gradiente): -0.02048
# b: -0.53122
# b (gradiente): 0.12602
# ===============================
# Epoch:  679
# Custo: 0.45189389586448669434
# m: 0.29310
# m (gradiente): -0.02042
# b: -0.54380
# b (gradiente): 0.12549
# ===============================
# Epoch:  689
# Custo: 0.45028361678123474121
# m: 0.29514
# m (gradiente): -0.02035
# b: -0.55632
# b (gradiente): 0.12497
# ===============================
# Epoch:  699
# Custo: 0.44868659973144531250
# m: 0.29717
# m (gradiente): -0.02029
# b: -0.56879
# b (gradiente): 0.12446
# ===============================
# Epoch:  709
# Custo: 0.44710272550582885742
# m: 0.29920
# m (gradiente): -0.02022
# b: -0.58120
# b (gradiente): 0.12394
# ===============================
# Epoch:  719
# Custo: 0.44553184509277343750
# m: 0.30122
# m (gradiente): -0.02016
# b: -0.59357
# b (gradiente): 0.12343
# ===============================
# Epoch:  729
# Custo: 0.44397377967834472656
# m: 0.30323
# m (gradiente): -0.02009
# b: -0.60588
# b (gradiente): 0.12292
# ===============================
# Epoch:  739
# Custo: 0.44242849946022033691
# m: 0.30524
# m (gradiente): -0.02003
# b: -0.61815
# b (gradiente): 0.12241
# ===============================
# Epoch:  749
# Custo: 0.44089585542678833008
# m: 0.30724
# m (gradiente): -0.01997
# b: -0.63036
# b (gradiente): 0.12191
# ===============================
# Epoch:  759
# Custo: 0.43937563896179199219
# m: 0.30923
# m (gradiente): -0.01990
# b: -0.64253
# b (gradiente): 0.12141
# ===============================
# Epoch:  769
# Custo: 0.43786782026290893555
# m: 0.31122
# m (gradiente): -0.01984
# b: -0.65464
# b (gradiente): 0.12091
# ===============================
# Epoch:  779
# Custo: 0.43637228012084960938
# m: 0.31320
# m (gradiente): -0.01978
# b: -0.66670
# b (gradiente): 0.12042
# ===============================
# Epoch:  789
# Custo: 0.43488892912864685059
# m: 0.31517
# m (gradiente): -0.01971
# b: -0.67872
# b (gradiente): 0.11993
# ===============================
# Epoch:  799
# Custo: 0.43341749906539916992
# m: 0.31714
# m (gradiente): -0.01965
# b: -0.69068
# b (gradiente): 0.11944
# ===============================
# Epoch:  809
# Custo: 0.43195804953575134277
# m: 0.31910
# m (gradiente): -0.01959
# b: -0.70260
# b (gradiente): 0.11895
# ===============================
# Epoch:  819
# Custo: 0.43051037192344665527
# m: 0.32105
# m (gradiente): -0.01953
# b: -0.71447
# b (gradiente): 0.11847
# ===============================
# Epoch:  829
# Custo: 0.42907434701919555664
# m: 0.32300
# m (gradiente): -0.01946
# b: -0.72629
# b (gradiente): 0.11798
# ===============================
# Epoch:  839
# Custo: 0.42764991521835327148
# m: 0.32495
# m (gradiente): -0.01940
# b: -0.73806
# b (gradiente): 0.11751
# ===============================
# Epoch:  849
# Custo: 0.42623695731163024902
# m: 0.32688
# m (gradiente): -0.01934
# b: -0.74978
# b (gradiente): 0.11703
# ===============================
# Epoch:  859
# Custo: 0.42483535408973693848
# m: 0.32881
# m (gradiente): -0.01928
# b: -0.76146
# b (gradiente): 0.11656
# ===============================
# Epoch:  869
# Custo: 0.42344492673873901367
# m: 0.33074
# m (gradiente): -0.01922
# b: -0.77309
# b (gradiente): 0.11609
# ===============================
# Epoch:  879
# Custo: 0.42206564545631408691
# m: 0.33266
# m (gradiente): -0.01916
# b: -0.78467
# b (gradiente): 0.11562
# ===============================
# Epoch:  889
# Custo: 0.42069730162620544434
# m: 0.33457
# m (gradiente): -0.01910
# b: -0.79621
# b (gradiente): 0.11516
# ===============================
# Epoch:  899
# Custo: 0.41933995485305786133
# m: 0.33647
# m (gradiente): -0.01904
# b: -0.80770
# b (gradiente): 0.11469
# ===============================
# Epoch:  909
# Custo: 0.41799336671829223633
# m: 0.33837
# m (gradiente): -0.01897
# b: -0.81915
# b (gradiente): 0.11423
# ===============================
# Epoch:  919
# Custo: 0.41665750741958618164
# m: 0.34027
# m (gradiente): -0.01891
# b: -0.83054
# b (gradiente): 0.11378
# ===============================
# Epoch:  929
# Custo: 0.41533216834068298340
# m: 0.34216
# m (gradiente): -0.01885
# b: -0.84190
# b (gradiente): 0.11332
# ===============================
# Epoch:  939
# Custo: 0.41401737928390502930
# m: 0.34404
# m (gradiente): -0.01879
# b: -0.85320
# b (gradiente): 0.11287
# ===============================
# Epoch:  949
# Custo: 0.41271296143531799316
# m: 0.34592
# m (gradiente): -0.01874
# b: -0.86447
# b (gradiente): 0.11242
# ===============================
# Epoch:  959
# Custo: 0.41141876578330993652
# m: 0.34779
# m (gradiente): -0.01868
# b: -0.87568
# b (gradiente): 0.11198
# ===============================
# Epoch:  969
# Custo: 0.41013485193252563477
# m: 0.34965
# m (gradiente): -0.01862
# b: -0.88686
# b (gradiente): 0.11153
# ===============================
# Epoch:  979
# Custo: 0.40886092185974121094
# m: 0.35151
# m (gradiente): -0.01856
# b: -0.89799
# b (gradiente): 0.11109
# ===============================
# Epoch:  989
# Custo: 0.40759697556495666504
# m: 0.35336
# m (gradiente): -0.01850
# b: -0.90907
# b (gradiente): 0.11066
# ===============================
# Epoch:  999
# Custo: 0.40634298324584960938
# m: 0.35521
# m (gradiente): -0.01844
# b: -0.92011
# b (gradiente): 0.11022
# ===============================
# Epoch:  1009
# Custo: 0.40509867668151855469
# m: 0.35705
# m (gradiente): -0.01839
# b: -0.93111
# b (gradiente): 0.10979
# ===============================
# Epoch:  1019
# Custo: 0.40386420488357543945
# m: 0.35889
# m (gradiente): -0.01833
# b: -0.94207
# b (gradiente): 0.10936
# ===============================
# Epoch:  1029
# Custo: 0.40263921022415161133
# m: 0.36072
# m (gradiente): -0.01827
# b: -0.95298
# b (gradiente): 0.10893
# ===============================
# Epoch:  1039
# Custo: 0.40142369270324707031
# m: 0.36254
# m (gradiente): -0.01821
# b: -0.96385
# b (gradiente): 0.10851
# ===============================
# Epoch:  1049
# Custo: 0.40021762251853942871
# m: 0.36436
# m (gradiente): -0.01816
# b: -0.97468
# b (gradiente): 0.10808
# ===============================
# Epoch:  1059
# Custo: 0.39902091026306152344
# m: 0.36617
# m (gradiente): -0.01810
# b: -0.98546
# b (gradiente): 0.10766
# ===============================
# Epoch:  1069
# Custo: 0.39783334732055664062
# m: 0.36798
# m (gradiente): -0.01804
# b: -0.99621
# b (gradiente): 0.10725
# ===============================
# Epoch:  1079
# Custo: 0.39665496349334716797
# m: 0.36978
# m (gradiente): -0.01799
# b: -1.00691
# b (gradiente): 0.10683
# ===============================
# Epoch:  1089
# Custo: 0.39548563957214355469
# m: 0.37157
# m (gradiente): -0.01793
# b: -1.01757
# b (gradiente): 0.10642
# ===============================
# Epoch:  1099
# Custo: 0.39432519674301147461
# m: 0.37337
# m (gradiente): -0.01788
# b: -1.02819
# b (gradiente): 0.10601
# ===============================
# Epoch:  1109
# Custo: 0.39317366480827331543
# m: 0.37515
# m (gradiente): -0.01782
# b: -1.03876
# b (gradiente): 0.10560
# ===============================
# Epoch:  1119
# Custo: 0.39203089475631713867
# m: 0.37693
# m (gradiente): -0.01777
# b: -1.04930
# b (gradiente): 0.10520
# ===============================
# Epoch:  1129
# Custo: 0.39089679718017578125
# m: 0.37870
# m (gradiente): -0.01771
# b: -1.05980
# b (gradiente): 0.10479
# ===============================
# Epoch:  1139
# Custo: 0.38977134227752685547
# m: 0.38047
# m (gradiente): -0.01766
# b: -1.07026
# b (gradiente): 0.10439
# ===============================
# Epoch:  1149
# Custo: 0.38865441083908081055
# m: 0.38223
# m (gradiente): -0.01760
# b: -1.08068
# b (gradiente): 0.10400
# ===============================
# Epoch:  1159
# Custo: 0.38754579424858093262
# m: 0.38399
# m (gradiente): -0.01755
# b: -1.09105
# b (gradiente): 0.10360
# ===============================
# Epoch:  1169
# Custo: 0.38644564151763916016
# m: 0.38574
# m (gradiente): -0.01750
# b: -1.10139
# b (gradiente): 0.10321
# ===============================
# Epoch:  1179
# Custo: 0.38535377383232116699
# m: 0.38749
# m (gradiente): -0.01744
# b: -1.11169
# b (gradiente): 0.10282
# ===============================
# Epoch:  1189
# Custo: 0.38427004218101501465
# m: 0.38923
# m (gradiente): -0.01739
# b: -1.12195
# b (gradiente): 0.10243
# ===============================
# Epoch:  1199
# Custo: 0.38319450616836547852
# m: 0.39097
# m (gradiente): -0.01734
# b: -1.13217
# b (gradiente): 0.10204
# ===============================
# Epoch:  1209
# Custo: 0.38212689757347106934
# m: 0.39270
# m (gradiente): -0.01728
# b: -1.14236
# b (gradiente): 0.10166
# ===============================
# Epoch:  1219
# Custo: 0.38106724619865417480
# m: 0.39442
# m (gradiente): -0.01723
# b: -1.15250
# b (gradiente): 0.10128
# ===============================
# Epoch:  1229
# Custo: 0.38001555204391479492
# m: 0.39614
# m (gradiente): -0.01718
# b: -1.16261
# b (gradiente): 0.10090
# ===============================
# Epoch:  1239
# Custo: 0.37897157669067382812
# m: 0.39786
# m (gradiente): -0.01713
# b: -1.17268
# b (gradiente): 0.10053
# ===============================
# Epoch:  1249
# Custo: 0.37793537974357604980
# m: 0.39957
# m (gradiente): -0.01708
# b: -1.18271
# b (gradiente): 0.10015
# ===============================
# Epoch:  1259
# Custo: 0.37690675258636474609
# m: 0.40127
# m (gradiente): -0.01702
# b: -1.19271
# b (gradiente): 0.09978
# ===============================
# Epoch:  1269
# Custo: 0.37588572502136230469
# m: 0.40297
# m (gradiente): -0.01697
# b: -1.20266
# b (gradiente): 0.09941
# ===============================
# Epoch:  1279
# Custo: 0.37487220764160156250
# m: 0.40467
# m (gradiente): -0.01692
# b: -1.21258
# b (gradiente): 0.09904
# ===============================
# Epoch:  1289
# Custo: 0.37386614084243774414
# m: 0.40636
# m (gradiente): -0.01687
# b: -1.22247
# b (gradiente): 0.09868
# ===============================
# Epoch:  1299
# Custo: 0.37286731600761413574
# m: 0.40804
# m (gradiente): -0.01682
# b: -1.23232
# b (gradiente): 0.09832
# ===============================
# Epoch:  1309
# Custo: 0.37187591195106506348
# m: 0.40972
# m (gradiente): -0.01677
# b: -1.24213
# b (gradiente): 0.09796
# ===============================
# Epoch:  1319
# Custo: 0.37089166045188903809
# m: 0.41139
# m (gradiente): -0.01672
# b: -1.25190
# b (gradiente): 0.09760
# ===============================
# Epoch:  1329
# Custo: 0.36991459131240844727
# m: 0.41306
# m (gradiente): -0.01667
# b: -1.26164
# b (gradiente): 0.09724
# ===============================
# Epoch:  1339
# Custo: 0.36894449591636657715
# m: 0.41473
# m (gradiente): -0.01662
# b: -1.27135
# b (gradiente): 0.09689
# ===============================
# Epoch:  1349
# Custo: 0.36798143386840820312
# m: 0.41639
# m (gradiente): -0.01657
# b: -1.28102
# b (gradiente): 0.09654
# ===============================
# Epoch:  1359
# Custo: 0.36702531576156616211
# m: 0.41804
# m (gradiente): -0.01652
# b: -1.29065
# b (gradiente): 0.09619
# ===============================
# Epoch:  1369
# Custo: 0.36607602238655090332
# m: 0.41969
# m (gradiente): -0.01647
# b: -1.30025
# b (gradiente): 0.09584
# ===============================
# Epoch:  1379
# Custo: 0.36513355374336242676
# m: 0.42134
# m (gradiente): -0.01642
# b: -1.30982
# b (gradiente): 0.09550
# ===============================
# Epoch:  1389
# Custo: 0.36419782042503356934
# m: 0.42298
# m (gradiente): -0.01638
# b: -1.31935
# b (gradiente): 0.09515
# ===============================
# Epoch:  1399
# Custo: 0.36326879262924194336
# m: 0.42461
# m (gradiente): -0.01633
# b: -1.32884
# b (gradiente): 0.09481
# ===============================
# Epoch:  1409
# Custo: 0.36234623193740844727
# m: 0.42624
# m (gradiente): -0.01628
# b: -1.33831
# b (gradiente): 0.09447
# ===============================
# Epoch:  1419
# Custo: 0.36143034696578979492
# m: 0.42787
# m (gradiente): -0.01623
# b: -1.34774
# b (gradiente): 0.09414
# ===============================
# Epoch:  1429
# Custo: 0.36052089929580688477
# m: 0.42949
# m (gradiente): -0.01618
# b: -1.35713
# b (gradiente): 0.09380
# ===============================
# Epoch:  1439
# Custo: 0.35961782932281494141
# m: 0.43110
# m (gradiente): -0.01614
# b: -1.36649
# b (gradiente): 0.09347
# ===============================
# Epoch:  1449
# Custo: 0.35872113704681396484
# m: 0.43271
# m (gradiente): -0.01609
# b: -1.37582
# b (gradiente): 0.09314
# ===============================
# Epoch:  1459
# Custo: 0.35783076286315917969
# m: 0.43432
# m (gradiente): -0.01604
# b: -1.38512
# b (gradiente): 0.09281
# ===============================
# Epoch:  1469
# Custo: 0.35694652795791625977
# m: 0.43592
# m (gradiente): -0.01600
# b: -1.39438
# b (gradiente): 0.09248
# ===============================
# Epoch:  1479
# Custo: 0.35606858134269714355
# m: 0.43752
# m (gradiente): -0.01595
# b: -1.40361
# b (gradiente): 0.09216
# ===============================
# Epoch:  1489
# Custo: 0.35519668459892272949
# m: 0.43911
# m (gradiente): -0.01591
# b: -1.41281
# b (gradiente): 0.09184
# ===============================
# Epoch:  1499
# Custo: 0.35433083772659301758
# m: 0.44070
# m (gradiente): -0.01586
# b: -1.42198
# b (gradiente): 0.09152
# ===============================
# Epoch:  1509
# Custo: 0.35347101092338562012
# m: 0.44228
# m (gradiente): -0.01581
# b: -1.43111
# b (gradiente): 0.09120
# ===============================
# Epoch:  1519
# Custo: 0.35261708498001098633
# m: 0.44386
# m (gradiente): -0.01577
# b: -1.44021
# b (gradiente): 0.09088
# ===============================
# Epoch:  1529
# Custo: 0.35176903009414672852
# m: 0.44544
# m (gradiente): -0.01572
# b: -1.44928
# b (gradiente): 0.09057
# ===============================
# Epoch:  1539
# Custo: 0.35092681646347045898
# m: 0.44701
# m (gradiente): -0.01568
# b: -1.45832
# b (gradiente): 0.09025
# ===============================
# Epoch:  1549
# Custo: 0.35009041428565979004
# m: 0.44857
# m (gradiente): -0.01563
# b: -1.46733
# b (gradiente): 0.08994
# ===============================
# Epoch:  1559
# Custo: 0.34925970435142517090
# m: 0.45013
# m (gradiente): -0.01559
# b: -1.47631
# b (gradiente): 0.08963
# ===============================
# Epoch:  1569
# Custo: 0.34843465685844421387
# m: 0.45169
# m (gradiente): -0.01554
# b: -1.48526
# b (gradiente): 0.08933
# ===============================
# Epoch:  1579
# Custo: 0.34761524200439453125
# m: 0.45324
# m (gradiente): -0.01550
# b: -1.49417
# b (gradiente): 0.08902
# ===============================
# Epoch:  1589
# Custo: 0.34680137038230895996
# m: 0.45479
# m (gradiente): -0.01546
# b: -1.50306
# b (gradiente): 0.08872
# ===============================
# Epoch:  1599
# Custo: 0.34599289298057556152
# m: 0.45633
# m (gradiente): -0.01541
# b: -1.51191
# b (gradiente): 0.08842
# ===============================
# Epoch:  1609
# Custo: 0.34519004821777343750
# m: 0.45787
# m (gradiente): -0.01537
# b: -1.52074
# b (gradiente): 0.08812
# ===============================
# Epoch:  1619
# Custo: 0.34439244866371154785
# m: 0.45941
# m (gradiente): -0.01533
# b: -1.52953
# b (gradiente): 0.08782
# ===============================
# Epoch:  1629
# Custo: 0.34360030293464660645
# m: 0.46094
# m (gradiente): -0.01528
# b: -1.53830
# b (gradiente): 0.08752
# ===============================
# Epoch:  1639
# Custo: 0.34281343221664428711
# m: 0.46246
# m (gradiente): -0.01524
# b: -1.54703
# b (gradiente): 0.08723
# ===============================
# Epoch:  1649
# Custo: 0.34203177690505981445
# m: 0.46399
# m (gradiente): -0.01520
# b: -1.55574
# b (gradiente): 0.08694
# ===============================
# Epoch:  1659
# Custo: 0.34125533699989318848
# m: 0.46550
# m (gradiente): -0.01516
# b: -1.56442
# b (gradiente): 0.08665
# ===============================
# Epoch:  1669
# Custo: 0.34048402309417724609
# m: 0.46702
# m (gradiente): -0.01511
# b: -1.57307
# b (gradiente): 0.08636
# ===============================
# Epoch:  1679
# Custo: 0.33971783518791198730
# m: 0.46853
# m (gradiente): -0.01507
# b: -1.58169
# b (gradiente): 0.08607
# ===============================
# Epoch:  1689
# Custo: 0.33895674347877502441
# m: 0.47003
# m (gradiente): -0.01503
# b: -1.59028
# b (gradiente): 0.08578
# ===============================
# Epoch:  1699
# Custo: 0.33820050954818725586
# m: 0.47153
# m (gradiente): -0.01499
# b: -1.59884
# b (gradiente): 0.08550
# ===============================
# Epoch:  1709
# Custo: 0.33744937181472778320
# m: 0.47303
# m (gradiente): -0.01495
# b: -1.60738
# b (gradiente): 0.08522
# ===============================
# Epoch:  1719
# Custo: 0.33670312166213989258
# m: 0.47452
# m (gradiente): -0.01491
# b: -1.61588
# b (gradiente): 0.08494
# ===============================
# Epoch:  1729
# Custo: 0.33596175909042358398
# m: 0.47601
# m (gradiente): -0.01487
# b: -1.62436
# b (gradiente): 0.08466
# ===============================
# Epoch:  1739
# Custo: 0.33522528409957885742
# m: 0.47749
# m (gradiente): -0.01483
# b: -1.63281
# b (gradiente): 0.08438
# ===============================
# Epoch:  1749
# Custo: 0.33449348807334899902
# m: 0.47897
# m (gradiente): -0.01479
# b: -1.64123
# b (gradiente): 0.08411
# ===============================
# Epoch:  1759
# Custo: 0.33376646041870117188
# m: 0.48045
# m (gradiente): -0.01475
# b: -1.64963
# b (gradiente): 0.08383
# ===============================
# Epoch:  1769
# Custo: 0.33304411172866821289
# m: 0.48192
# m (gradiente): -0.01471
# b: -1.65800
# b (gradiente): 0.08356
# ===============================
# Epoch:  1779
# Custo: 0.33232638239860534668
# m: 0.48339
# m (gradiente): -0.01467
# b: -1.66634
# b (gradiente): 0.08329
# ===============================
# Epoch:  1789
# Custo: 0.33161333203315734863
# m: 0.48486
# m (gradiente): -0.01463
# b: -1.67465
# b (gradiente): 0.08302
# ===============================
# Epoch:  1799
# Custo: 0.33090481162071228027
# m: 0.48632
# m (gradiente): -0.01459
# b: -1.68294
# b (gradiente): 0.08276
# ===============================
# Epoch:  1809
# Custo: 0.33020082116127014160
# m: 0.48777
# m (gradiente): -0.01455
# b: -1.69120
# b (gradiente): 0.08249
# ===============================
# Epoch:  1819
# Custo: 0.32950133085250854492
# m: 0.48923
# m (gradiente): -0.01451
# b: -1.69944
# b (gradiente): 0.08223
# ===============================
# Epoch:  1829
# Custo: 0.32880625128746032715
# m: 0.49067
# m (gradiente): -0.01447
# b: -1.70765
# b (gradiente): 0.08196
# ===============================
# Epoch:  1839
# Custo: 0.32811561226844787598
# m: 0.49212
# m (gradiente): -0.01443
# b: -1.71583
# b (gradiente): 0.08170
# ===============================
# Epoch:  1849
# Custo: 0.32742929458618164062
# m: 0.49356
# m (gradiente): -0.01439
# b: -1.72398
# b (gradiente): 0.08144
# ===============================
# Epoch:  1859
# Custo: 0.32674732804298400879
# m: 0.49500
# m (gradiente): -0.01435
# b: -1.73211
# b (gradiente): 0.08119
# ===============================
# Epoch:  1869
# Custo: 0.32606962323188781738
# m: 0.49643
# m (gradiente): -0.01432
# b: -1.74022
# b (gradiente): 0.08093
# ===============================
# Epoch:  1879
# Custo: 0.32539618015289306641
# m: 0.49786
# m (gradiente): -0.01428
# b: -1.74830
# b (gradiente): 0.08068
# ===============================
# Epoch:  1889
# Custo: 0.32472690939903259277
# m: 0.49929
# m (gradiente): -0.01424
# b: -1.75635
# b (gradiente): 0.08042
# ===============================
# Epoch:  1899
# Custo: 0.32406184077262878418
# m: 0.50071
# m (gradiente): -0.01420
# b: -1.76438
# b (gradiente): 0.08017
# ===============================
# Epoch:  1909
# Custo: 0.32340091466903686523
# m: 0.50213
# m (gradiente): -0.01417
# b: -1.77238
# b (gradiente): 0.07992
# ===============================
# Epoch:  1919
# Custo: 0.32274404168128967285
# m: 0.50354
# m (gradiente): -0.01413
# b: -1.78036
# b (gradiente): 0.07967
# ===============================
# Epoch:  1929
# Custo: 0.32209125161170959473
# m: 0.50495
# m (gradiente): -0.01409
# b: -1.78831
# b (gradiente): 0.07942
# ===============================
# Epoch:  1939
# Custo: 0.32144248485565185547
# m: 0.50636
# m (gradiente): -0.01406
# b: -1.79624
# b (gradiente): 0.07918
# ===============================
# Epoch:  1949
# Custo: 0.32079771161079406738
# m: 0.50776
# m (gradiente): -0.01402
# b: -1.80415
# b (gradiente): 0.07893
# ===============================
# Epoch:  1959
# Custo: 0.32015687227249145508
# m: 0.50916
# m (gradiente): -0.01398
# b: -1.81203
# b (gradiente): 0.07869
# ===============================
# Epoch:  1969
# Custo: 0.31951993703842163086
# m: 0.51056
# m (gradiente): -0.01395
# b: -1.81988
# b (gradiente): 0.07845
# ===============================
# Epoch:  1979
# Custo: 0.31888690590858459473
# m: 0.51195
# m (gradiente): -0.01391
# b: -1.82772
# b (gradiente): 0.07821
# ===============================
# Epoch:  1989
# Custo: 0.31825762987136840820
# m: 0.51334
# m (gradiente): -0.01388
# b: -1.83552
# b (gradiente): 0.07797
# ===============================
# Epoch:  1999
# Custo: 0.31763225793838500977
# m: 0.51473
# m (gradiente): -0.01384
# b: -1.84331
# b (gradiente): 0.07773

# %% [markdown]
# ### Plotando o gráfico da Função de Custo

# %%
print("GRÁFICO DA FUNÇÃO DE CUSTO")
plt.plot(contador_custo, 'b')
plt.show()
# Out:
# GRÁFICO DA FUNÇÃO DE CUSTO

# %% [markdown]
# ### Fazendo a prefição

# %%
teste = np.array([2, 3, 6, 7, 8])
t_teste = torch.from_numpy(teste.astype(np.float32))
t_teste = t_teste.view(t_teste.shape[0], 1)

with torch.no_grad():
  predicoes = model(t_teste)
  for x, y in zip(t_teste, predicoes):
    #definindo o cutoff / threshold
    status = ""
    if (y >= 0.7):
      status = "aprovado"
    else:
      status = "reprovado"
    print ('x: {:.2f} | ŷ: {:.2f} | '.format(x.detach().item(),y.detach().item()), status)
# Out:
# x: 2.00 | ŷ: 0.31 |  reprovado
# x: 3.00 | ŷ: 0.43 |  reprovado
# x: 6.00 | ŷ: 0.78 |  aprovado
# x: 7.00 | ŷ: 0.85 |  aprovado
# x: 8.00 | ŷ: 0.91 |  aprovado
