# %% [markdown]
# <a href="https://colab.research.google.com/github/idcesares/Clube-de-STEM-IA-ESEM/blob/master/Workshop_Math_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1º Caso: Equação de 2º grau** ##

# %% [markdown]
# ## **Forma Geral da Equação do Segundo Grau** ##
# ## **ax² + bx + c = 0** ##
#
# ![ac3f6f0949d6f51562d2ea0615f5150a.jpg](data:image/jpeg;base64,...)
#
#
#
#
#
# Algumas regras, que devemos entender antes de iniciar:
#
# *  O valor de a não pode ser igual a zero;
# *  Delta negativo, a equação não possui raízes reais;
# *  Delta igual a zero, a equação possui raízes reais iguais; e
# *  Delta positivo, a equação possui duas raízes reais e distintas.

# %% [markdown]
# ## **2º Caso: Fatoração em números primos**
#
# Todo número natural, maior que 1, pode ser decomposto em um produto de dois ou mais fatores.
#
# ![Fatoração.png](data:image/png;base64,...)
#
# Fonte: https://aprovadonovestibular.com/raiz-quadrada-como-calcular.html
#
#  Decomposição de um número em fatores primos obedecendo uma sequência de tentativa.

# %% [markdown]
# **E se quisermos automatizar esse processo?**

# %% [markdown]
# ## **3º Caso: Calculadora de MRU** ##

# %% [markdown]
# **MOVIMENTO RETILÍNEO UNIFORME**
#
# ![27.jpg](data:image/jpeg;base64,...)
